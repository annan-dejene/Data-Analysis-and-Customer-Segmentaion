# %% [markdown]
# ## Merging different datasets

# %%
# Importing libraries
import pandas as pd

# %%
# Reading the different datasets
cust_dem = pd.read_csv(r"Exported/customer_demographic.csv") # Customer Demographic
trans = pd.read_csv(r"Exported/transactions.csv") # Transactions 
cust_add = pd.read_csv(r"Exported/customer_address.csv") # Customer Address

# %% [markdown]
# ### __`Let's First combine Customer Demographic with Customer Address`__

# %%
# Viewing customer demographic
cust_dem.head()
# Out:
#    customer_id      first_name  last_name gender  \
# 0            1         Laraine  Medendorp      F
# 1            2             Eli    Bockman      M
# 2            3           Arlin     Dearle      M
# 3            4          Talbot        NaN      M
# 4            5  Sheila-kathryn     Calton      F
#
#    past_3_years_bike_related_purchases         DOB  age  \
# 0                                   93  1953-10-12   67
# 1                                   81  1980-12-16   40
# 2                                   61  1954-01-20   66
# 3                                   33  1961-10-03   59
# 4                                   56  1977-05-13   43
#
#                 job_title job_industry_category     wealth_segment owns_car  \
# 0     Executive Secretary                Health      Mass Customer      Yes
# 1  Administrative Officer    Financial Services      Mass Customer      Yes
# 2      Recruiting Manager              Property      Mass Customer      Yes
# 3                Untitled                    IT      Mass Customer       No
# 4           Senior Editor              Untitled  Affluent Customer      Yes
#
#    tenure
# 0    11.0
# 1    16.0
# 2    15.0
# 3     7.0
# 4     8.0

# %%
# Viewing customer address
cust_add.head()
# Out:
#    customer_id              address  postcode state  property_valuation
# 0            1   060 Morning Avenue      2016   NSW                  10
# 1            2  6 Meadow Vale Court      2153   NSW                  10
# 2            4   0 Holy Cross Court      4211   QLD                   9
# 3            5  17979 Del Mar Point      2448   NSW                   4
# 4            6     9 Oakridge Court      3216   VIC                   9

# %% [markdown]
# ### - ___**`We can see that both of the datasets have a customer id column so we can concatenate those two datasets on that column`**___

# %%
# Merging the customer demographic and customer address datasets to form a new one.
cust_data = pd.merge(cust_dem, cust_add, on="customer_id")

# %%
# The dataset is now combined form of the customer address and customer demographic.
cust_data.head()
# Out:
#    customer_id      first_name  last_name gender  \
# 0            1         Laraine  Medendorp      F
# 1            2             Eli    Bockman      M
# 2            4          Talbot        NaN      M
# 3            5  Sheila-kathryn     Calton      F
# 4            6            Curr  Duckhouse      M
#
#    past_3_years_bike_related_purchases         DOB  age  \
# 0                                   93  1953-10-12   67
# 1                                   81  1980-12-16   40
# 2                                   33  1961-10-03   59
# 3                                   56  1977-05-13   43
# 4                                   35  1966-09-16   54
#
#                 job_title job_industry_category     wealth_segment owns_car  \
# 0     Executive Secretary                Health      Mass Customer      Yes
# 1  Administrative Officer    Financial Services      Mass Customer      Yes
# 2                Untitled                    IT      Mass Customer       No
# 3           Senior Editor              Untitled  Affluent Customer      Yes
# 4                Untitled                Retail     High Net Worth      Yes
#
#    tenure              address  postcode state  property_valuation
# 0    11.0   060 Morning Avenue      2016   NSW                  10
# 1    16.0  6 Meadow Vale Court      2153   NSW                  10
# 2     7.0   0 Holy Cross Court      4211   QLD                   9
# 3     8.0  17979 Del Mar Point      2448   NSW                   4
# 4    13.0     9 Oakridge Court      3216   VIC                   9

# %% [markdown]
# ### __`Now we will combine total Customer Dataset with the Transaction Dataset`__

# %%
pd.options.display.max_columns = 30

# %%
trans.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost   profit product_first_sold_date
# 0       71.49          53.62    17.87              2012-12-02
# 1     2091.47         388.92  1702.55              2014-03-03
# 2     1793.43         248.82  1544.61              1999-07-20
# 3     1198.46         381.10   817.36              1998-12-16
# 4     1765.30         709.48  1055.82              2015-08-10

# %%
# Merging the Transaction and Customer data to get all the data about customers including their transactions..
customer = pd.merge(trans, cust_data, on="customer_id")

# %%
customer.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved  Giant Bicycles     Standard        medium       medium
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved  Giant Bicycles     Standard          high       medium
#
#    list_price  standard_cost   profit product_first_sold_date first_name  \
# 0       71.49          53.62    17.87              2012-12-02    Kristos
# 1     1403.50         954.82   448.68              2003-02-07    Kristos
# 2      478.16         298.72   179.44              2010-11-05    Kristos
# 3     2091.47         388.92  1702.55              2014-03-03     Lauree
# 4     1129.13         677.48   451.65              2011-04-16     Lauree
#
#    last_name gender  past_3_years_bike_related_purchases         DOB  age  \
# 0    Anthony      M                                   19  1955-01-11   65
# 1    Anthony      M                                   19  1955-01-11   65
# 2    Anthony      M                                   19  1955-01-11   65
# 3  O'Donnell      F                                   89  1979-02-04   41
# 4  O'Donnell      F                                   89  1979-02-04   41
#
#              job_title job_industry_category wealth_segment owns_car  tenure  \
# 0  Software Engineer I    Financial Services  Mass Customer      Yes    10.0
# 1  Software Engineer I    Financial Services  Mass Customer      Yes    10.0
# 2  Software Engineer I    Financial Services  Mass Customer      Yes    10.0
# 3  Clinical Specialist                Health  Mass Customer      Yes    10.0
# 4  Clinical Specialist                Health  Mass Customer      Yes    10.0
#
#              address  postcode state  property_valuation
# 0  984 Hoepker Court      3064   VIC                   6
# 1  984 Hoepker Court      3064   VIC                   6
# 2  984 Hoepker Court      3064   VIC                   6
# 3    4 Shopko Circle      2196   NSW                   5
# 4    4 Shopko Circle      2196   NSW                   5

# %% [markdown]
# ### Now this dataset includes all information about each customer demographics, address and transaction data.

# %% [markdown]
# ### we will now export this final dataset

# %%
customer.to_csv(r"Exported/all_customers_data.csv", index=False)
